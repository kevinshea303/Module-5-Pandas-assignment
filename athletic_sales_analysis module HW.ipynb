# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
ath_sales_2020_df = pd.read_csv('Resources/athletic_sales_2020.csv')
ath_sales_2021_df = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
ath_sales_2020_df.head()
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    total_sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %%
# Display the 2021 sales DataFrame
ath_sales_2021_df.head()
# Out:
#     retailer  retailer_id invoice_date   region       state           city  \
# 0  West Gear      1128299       1/1/21     West  California  San Francisco
# 1  West Gear      1128299       1/1/21     West  California  San Francisco
# 2     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 3     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 4  West Gear      1128299       1/1/21     West  California  San Francisco
#
#                    product  price_per_unit  units_sold  total_sales  \
# 0  Men's Athletic Footwear              65         750       487500
# 1  Men's Athletic Footwear              51         233        11883
# 2            Men's Apparel              50         275       137500
# 3            Men's Apparel              47          77         3619
# 4  Men's Athletic Footwear              64         225        14400
#
#    operating_profit sales_method
# 0         121875.00       Outlet
# 1           3208.41       Outlet
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
ath_sales_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
ath_sales_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combined_df = pd.concat([ath_sales_2020_df, ath_sales_2021_df], axis='rows', join='inner')
combined_df.head(20)
# Out:
#        retailer  retailer_id invoice_date     region         state  \
# 0   Foot Locker      1185732       1/1/20  Northeast      New York
# 1   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3   Foot Locker      1185732       1/1/20  Northeast      New York
# 4   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 5   Foot Locker      1185732       1/1/20  Northeast      New York
# 6     West Gear      1128299       1/2/20  Northeast  Pennsylvania
# 7     West Gear      1128299       1/2/20  Northeast  Pennsylvania
# 8   Foot Locker      1185732       1/2/20  Northeast      New York
# 9     West Gear      1128299       1/2/20  Northeast  Pennsylvania
# 10  Foot Locker      1185732       1/2/20  Northeast      New York
# 11  Foot Locker      1185732       1/2/20  Northeast      New York
# 12    West Gear      1128299       1/3/20  Northeast  Pennsylvania
# ...

# %%
print(pd.isnull(combined_df))
# Out:
#       retailer  retailer_id  invoice_date  region  state   city  product  \
# 0        False        False         False   False  False  False    False
# 1        False        False         False   False  False  False    False
# 2        False        False         False   False  False  False    False
# 3        False        False         False   False  False  False    False
# 4        False        False         False   False  False  False    False
# ...        ...          ...           ...     ...    ...    ...      ...
# 8341     False        False         False   False  False  False    False
# 8342     False        False         False   False  False  False    False
# 8343     False        False         False   False  False  False    False
# 8344     False        False         False   False  False  False    False
# 8345     False        False         False   False  False  False    False
#
#       price_per_unit  units_sold  total_sales  operating_profit  sales_method
# ...

# %%
# Check if any values are null.
null_ath_values = combined_df.isnull()
print(null_ath_values)
# Out:
#       retailer  retailer_id  invoice_date  region  state   city  product  \
# 0        False        False         False   False  False  False    False
# 1        False        False         False   False  False  False    False
# 2        False        False         False   False  False  False    False
# 3        False        False         False   False  False  False    False
# 4        False        False         False   False  False  False    False
# ...        ...          ...           ...     ...    ...    ...      ...
# 8341     False        False         False   False  False  False    False
# 8342     False        False         False   False  False  False    False
# 8343     False        False         False   False  False  False    False
# 8344     False        False         False   False  False  False    False
# 8345     False        False         False   False  False  False    False
#
#       price_per_unit  units_sold  total_sales  operating_profit  sales_method
# ...

# %%
# Check the data type of each column
combined_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
renamed_df = combined_df.rename(columns={'invoice_date': 'datetime'})
renamed_df
# Out:
#          retailer  retailer_id  datetime     region         state  \
# 0     Foot Locker      1185732    1/1/20  Northeast      New York
# 1     Foot Locker      1185732    1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732    1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732    1/1/20  Northeast      New York
# 4     Foot Locker      1185732    1/1/20  Northeast  Pennsylvania
# ...           ...          ...       ...        ...           ...
# 8341  Foot Locker      1185732  12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732  12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732  12/31/21  Northeast         Maine
# 8344       Amazon      1185732  12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732  12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# 0         New York  Men's Street Footwear              50        1200
# ...

# %%
# Confirm that the "invoice_date" data type has been changed.
renamed_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# datetime             object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
#grouped_df = renamed_df.groupby(['state'])
#print(grouped_df)
#grouped_df.count().head(30)
# Out:
# ...
#                retailer  retailer_id  datetime  region  city  product  \
# state
# Alabama             216          216       216     216   216      216
# Alaska              144          144       144     144   144      144
# Arizona             216          216       216     216   216      216
# Arkansas            216          216       216     216   216      216
# California          429          429       429     429   429      429
# Colorado            144          144       144     144   144      144
# Connecticut         216          216       216     216   216      216
# Delaware            144          144       144     144   144      144
# Florida             360          360       360     360   360      360
# Georgia             216          216       216     216   216      216
# Hawaii              144          144       144     144   144      144
# Idaho               216          216       216     216   216      216
# ...

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
grouped_df = renamed_df.groupby(['state', 'region', 'city'])['units_sold'].sum().reset_index()
grouped_df = grouped_df.rename(columns={'units_sold': 'Total_Products_Sold'})
# Show the top 5 results.
top_5_df = grouped_df.nlargest(5, 'Total_Products_Sold')
print(top_5_df)
# Out:
#          state     region           city  Total_Products_Sold
# 34    New York  Northeast       New York               111954
# 46       Texas      South        Houston                90322
# 5   California       West  San Francisco                85478
# 4   California       West    Los Angeles                76384
# 9      Florida  Southeast          Miami                73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pivot_table = pd.pivot_table(grouped_df, index=['region', 'state', 'city'], values='Total_Products_Sold', aggfunc='sum')

# Rename the "units_sold" column to "Total_Products_Sold"
#already DONE

# Show the top 5 results.
top_5_pivot_df = pivot_table.nlargest(5, 'Total_Products_Sold')
print(top_5_pivot_df)
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
most_region_sales = renamed_df.groupby(['region', 'state', 'city'])['units_sold'].sum().reset_index()
most_region_sales = most_region_sales.rename(columns={'total_sales': 'Total Sales'})
# Show the top 5 results.
most_region_sales# = renamed_df.nlargest(5, 'Total Sales')
# Out:
#        region           state            city  units_sold
# 0     Midwest        Illinois         Chicago       25407
# 1     Midwest         Indiana    Indianapolis       26332
# 2     Midwest            Iowa      Des Moines       23446
# 3     Midwest          Kansas         Wichita       29463
# 4     Midwest        Michigan         Detroit       50095
# 5     Midwest       Minnesota     Minneapolis       20415
# 6     Midwest        Missouri       St. Louis       36404
# 7     Midwest         Montana        Billings       42713
# 8     Midwest        Nebraska           Omaha       19154
# 9     Midwest    North Dakota           Fargo       22781
# 10    Midwest            Ohio        Columbus       47781
# 11    Midwest    South Dakota     Sioux Falls       22973
# 12    Midwest       Wisconsin       Milwaukee       23950
# 13  Northeast     Connecticut        Hartford       34696
# 14  Northeast        Delaware      Wilmington       30275
# ...

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_retail_df = renamed_df.groupby(['retailer', 'region', 'state', 'city'])['total_sales'].sum().reset_index()
grouped_retail_df = grouped_retail_df.rename(columns={'total_sales': 'Total Sales'})


# Show the top 5 results.
top_5_retail = grouped_retail_df.nlargest(5, 'Total Sales')
print(top_5_retail)
# Out:
#         retailer     region           state           city  Total Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
pivot_retailer = pd.pivot_table(renamed_df, index=['retailer', 'region', 'state', 'city'], values='total_sales', aggfunc='sum')
pivot_table = pivot_table.reset_index()
# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.
top_5_results = pivot_table.nlargest(5, 'total_sales')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13656\3211135182.py in ?()
#       1 # Show the total sales for the products sold for each retailer, region, state, and city.
#       2 pivot_retailer = pd.pivot_table(renamed_df, index=['retailer', 'region', 'state', 'city'], values='total_sales', aggfunc='sum')
# ----> 3 pivot_table = pivot_table.reset_index()
#       4 # Optional: Rename the "total_sales" column to "Total Sales"
#       5 pivot_table = pivot_table.rename(columns={'total_sales': 'Total Sales'})
#       6
#
# c:\Users\kevri\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
# ...

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
women_data = renamed_df[renamed_df['product'] == 'Women\'s Athletic Footwear']
women_data.head()
# Out:
#        retailer  retailer_id datetime     region         state          city  \
# 21  Foot Locker      1185732   1/4/20  Northeast      New York      New York
# 22  Foot Locker      1185732   1/4/20  Northeast      New York      New York
# 23  Foot Locker      1185732   1/4/20  Northeast      New York      New York
# 26    West Gear      1128299   1/5/20  Northeast  Pennsylvania  Philadelphia
# 27    West Gear      1128299   1/5/20  Northeast  Pennsylvania  Philadelphia
#
#                       product  price_per_unit  units_sold  total_sales  \
# 21  Women's Athletic Footwear              36         281        10116
# 22  Women's Athletic Footwear              41         247        10127
# 23  Women's Athletic Footwear              45         850       382500
# 26  Women's Athletic Footwear              45         300       135000
# 27  Women's Athletic Footwear              34          90         3060
#
#     operating_profit sales_method
# 21           3742.92       Outlet
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
women_data_group_df = women_data.groupby(['retailer', 'region', 'state'])['units_sold'].sum
women_data = women_data.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'})

# Show the top 5 results.
top_shoes = women_data.nlargest(5, ['Womens_Footwear_Units_Sold'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 3
#       1 # Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
#       2 # Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
# ----> 3 women_data_group_df = women_data.groupby(['retailer', 'region', 'state'])['units_sold'].sum
#       4 women_data = women_data.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'})
#       6 # Show the top 5 results.
#
# File c:\Users\kevri\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
# ...

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.


# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"


# Show the top 5 results.

# %% [markdown]
# ### 6. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the table.

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.


# Sort the resampled pivot table in descending order on "Total Sales".

# %% [markdown]
# ### 7.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.


# Sort the resampled pivot table in descending order on "Total Sales".
